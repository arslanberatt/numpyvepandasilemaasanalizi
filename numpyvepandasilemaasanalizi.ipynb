# %%
import numpy as np
import pandas as pd

# %%
data2=pd.read_csv("C:/Users/Berat/Downloads/2022-yazilimci-maaslari-main/maas-anketi.csv")
data.head()
# Out:
#     level                                position         tech_stack  \
# 0  Senior                                     CTO               .Net
# 1  Middle                      Back-end Developer               .Net
# 2  Junior             Embedded Software Developer     Python;C / C++
# 3  Senior      Mobile Application Developer (iOS)  Swift;Objective C
# 4  Middle  Mobile Application Developer (Android)        Java;Kotlin
#
#         experience gender                    company company_size work_type  \
# 0  15 Yıl ve üzeri  Erkek  Yazılım Evi & Danışmanlık  6 - 10 Kişi    Remote
# 1        3 - 5 Yıl  Erkek                   Kurumsal         250+    Remote
# 2        1 - 3 Yıl  Erkek                   Kurumsal         250+      Ofis
# 3      12 - 14 Yıl  Erkek                  E-Ticaret         250+      Ofis
# 4        3 - 5 Yıl  Erkek                      Banka         250+    Remote
#
#        city         currency             salary  raise_period
# ...

# %%
data=pd.read_csv("C:/Users/Berat/Downloads/2024-yazilim-sektoru-maaslari-onceki-yazilimci.csv")
data.head()
# Out:
#     level                                position         tech_stack  \
# 0  Senior                                     CTO               .Net
# 1  Middle                      Back-end Developer               .Net
# 2  Junior             Embedded Software Developer     Python;C / C++
# 3  Senior      Mobile Application Developer (iOS)  Swift;Objective C
# 4  Middle  Mobile Application Developer (Android)        Java;Kotlin
#
#         experience gender                    company company_size work_type  \
# 0  15 Yıl ve üzeri  Erkek  Yazılım Evi & Danışmanlık  6 - 10 Kişi    Remote
# 1        3 - 5 Yıl  Erkek                   Kurumsal         250+    Remote
# 2        1 - 3 Yıl  Erkek                   Kurumsal         250+      Ofis
# 3      12 - 14 Yıl  Erkek                  E-Ticaret         250+      Ofis
# 4        3 - 5 Yıl  Erkek                      Banka         250+    Remote
#
#        city         currency             salary  raise_period
# ...

# %%
data2=pd.read_csv("C:/Users/Berat/Downloads/2022-yazilimci-maaslari-main/maas-anketi.csv")
data2.iloc[:,2].head(20)
# Out:
# 0                                                   Php
# 1                                                 React
# 2                                                  .Net
# 3     Java, JavaScript | Html | Css, React, React Na...
# 4                         .Net, JavaScript | Html | Css
# 5                          Python, Kotlin, React Native
# 6                                                  .Net
# 7     .Net, JavaScript | Html | Css, Angular, React ...
# 8                          Php, JavaScript | Html | Css
# 9                 Php, Go, JavaScript | Html | Css, Vue
# 10                                  Swift / Objective C
# 11      JavaScript | Html | Css, React, Vue, Express.js
# 12                         JavaScript | Html | Css, Vue
# 13                         Swift / Objective C, Flutter
# 14                                                 Java
# 15                                                   Go
# 16                             Php, Swift / Objective C
# ...

# %%
data=pd.read_csv("C:/Users/Berat/Downloads/2024-yazilim-sektoru-maaslari-onceki-yazilimci.csv")
data.iloc[:,2].head(20)
# Out:
# 0                                   .Net
# 1                                   .Net
# 2                         Python;C / C++
# 3                      Swift;Objective C
# 4                            Java;Kotlin
# 5                                   Java
# 6                              Java;.Net
# 7                          .Net;Go;React
# 8     Java;JavaScript | Html | Css;Cobol
# 9                                   .Net
# 10                      Go;React;Angular
# 11                                 Plsql
# 12               JavaScript | Html | Css
# 13                          NodeJS;React
# 14                                 Swift
# 15                           Java;Python
# 16               Python;Power bi dax sql
# 17                                  Java
# 18                                  .Net
# 19                                  Java
# Name: tech_stack, dtype: object

# %%
data2=pd.read_csv("C:/Users/Berat/Downloads/2022-yazilimci-maaslari-main/maas-anketi.csv")
data2.iloc[:,11].head(20)
# Out:
# 0     15.000 TL - 15.999 TL
# 1       8.000 TL - 8.999 TL
# 2     15.000 TL - 15.999 TL
# 3     10.000 TL - 10.999 TL
# 4       5.000 TL - 5.999 TL
# 5     12.000 TL - 12.999 TL
# 6       8.000 TL - 8.999 TL
# 7                       NaN
# 8       7.000 TL - 7.999 TL
# 9     15.000 TL - 15.999 TL
# 10    24.000 TL - 24.999 TL
# 11      5.000 TL - 5.999 TL
# 12    21.000 TL - 21.999 TL
# 13                      NaN
# 14    21.000 TL - 21.999 TL
# 15    16.000 TL - 16.999 TL
# 16                      NaN
# 17    11.000 TL - 11.999 TL
# 18    25.000 TL - 25.999 TL
# 19      6.000 TL - 6.999 TL
# Name: salary_for_tl_currency, dtype: object

# %%
data=pd.read_csv("C:/Users/Berat/Downloads/2024-yazilim-sektoru-maaslari-onceki-yazilimci.csv")
data.iloc[:,10].head(20)
# Out:
# 0     150.000 - 154.999
# 1       46.000 - 46.999
# 2       39.000 - 39.999
# 3     125.000 - 129.999
# 4       75.000 - 79.999
# 5       50.000 - 50.999
# 6       80.000 - 84.999
# 7       38.000 - 38.999
# 8     115.000 - 119.999
# 9       95.000 - 99.999
# 10    175.000 - 179.999
# 11    130.000 - 134.999
# 12      19.000 - 19.999
# 13      30.000 - 30.999
# 14             200.000+
# 15        4.000 - 4.999
# 16      33.000 - 33.999
# 17        4.000 - 4.999
# 18      33.000 - 33.999
# 19    115.000 - 119.999
# Name: salary, dtype: object
